# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanbin-git/kaggle/blob/main/20250614.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. 라이브러리 설치  (재시작되면 다시 설치해야 함)
# !pip install -q wandb timm==0.9.12 torchvision --upgrade
# !pip install -q transformers==4.41.2

# %%
# 2. Drive 마운트 + 데이터 unzip
from google.colab import drive, files
drive.mount('/content/drive')

import os, zipfile, shutil
SRC_ZIP="/content/drive/MyDrive/open.zip"; DST_DIR="/content/open"
if os.path.exists(DST_DIR): shutil.rmtree(DST_DIR)
shutil.copy(SRC_ZIP, "/content/open.zip")
with zipfile.ZipFile("/content/open.zip") as z: z.extractall(DST_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
yaml_text = """
SEED: 42
IMG_SIZE: 456
BATCH_SIZE: 48
EPOCHS: 40
LEARNING_RATE: 0.0003
patience: 8
model: "tf_efficientnet_b5"
ema_decay: 0.9997
stochastic_depth: 0.2
train_root: "/content/open/train"
test_root : "/content/open/test"
"""
with open("config.yaml", "w") as f:
    f.write(yaml_text)
print("✅ config.yaml 저장 완료")
# Out:
# ✅ config.yaml 저장 완료

# %%
with open("dataload.py", "w") as f:
    f.write('''
import os, yaml, random, math
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
from torchvision.transforms import v2
from sklearn.model_selection import train_test_split
from PIL import Image

# ───────── config 로드 ─────────
with open("config.yaml") as cf:
    CFG = yaml.safe_load(cf)

# ───────── 시드 고정 ─────────
def seed_everything(seed:int):
    random.seed(seed); np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed); torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

# ───────── Dataset 정의 ─────────
class CustomImageDataset(Dataset):
    def __init__(self, root_dir, transform=None, is_test=False):
        self.root_dir, self.transform, self.is_test = root_dir, transform, is_test
        self.samples = []
        if is_test:
            for f in sorted(os.listdir(root_dir)):
                if f.lower().endswith(('.jpg','.jpeg','.png')):
                    self.samples.append((os.path.join(root_dir, f),))
        else:
            self.classes = sorted(os.listdir(root_dir))
            self.class_to_idx = {c:i for i,c in enumerate(self.classes)}
            for cls in self.classes:
                cls_dir = os.path.join(root_dir, cls)
                for f in os.listdir(cls_dir):
                    if f.lower().endswith(('.jpg','.jpeg','.png')):
                        self.samples.append((os.path.join(cls_dir, f), self.class_to_idx[cls]))

    def __len__(self): return len(self.samples)

    def __getitem__(self, idx):
        if self.is_test:
            path = self.samples[idx][0]
            img  = Image.open(path).convert("RGB")
            return self.transform(img) if self.transform else img
        path, label = self.samples[idx]
        img = Image.open(path).convert("RGB")
        if self.transform: img = self.transform(img)
        return img, label

# ───────── Transform ─────────
def get_transforms():
    train_tf = v2.Compose([
        v2.ToImage(), v2.ToDtype(torch.float32, scale=True),
        v2.RandomResizedCrop((CFG["IMG_SIZE"], CFG["IMG_SIZE"]), scale=(0.8,1.0)),
        v2.RandomHorizontalFlip(),
        v2.ColorJitter(0.3,0.3,0.3,0.1),
        v2.RandAugment(num_ops=2, magnitude=7),
        v2.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]),
    ])
    val_tf = v2.Compose([
        v2.ToImage(), v2.ToDtype(torch.float32, scale=True),
        v2.Resize((CFG["IMG_SIZE"], CFG["IMG_SIZE"])),
        v2.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225]),
    ])
    return train_tf, val_tf

# ───────── Loader ─────────
def get_loaders():
    seed_everything(CFG["SEED"])

    full = CustomImageDataset(CFG["train_root"])
    labels = [y for _, y in full.samples]
    tr_idx, val_idx = train_test_split(range(len(labels)),
                                       test_size=0.2,
                                       stratify=labels,
                                       random_state=CFG["SEED"])

    tr_tf, val_tf = get_transforms()
    train_ds = Subset(CustomImageDataset(CFG["train_root"], tr_tf), tr_idx)
    val_ds   = Subset(CustomImageDataset(CFG["train_root"], val_tf), val_idx)

    # ---- 불균형 보정 Sampler
    cls_cnt   = np.bincount([labels[i] for i in tr_idx])
    cls_wt    = 1. / (cls_cnt + 1e-6)
    sample_wt = [cls_wt[labels[i]] for i in tr_idx]
    sampler   = WeightedRandomSampler(sample_wt, num_samples=len(tr_idx), replacement=True)

    # ---- DataLoader 파라미터
    n_workers   = CFG.get("NUM_WORKERS", 8)
    prefetch    = CFG.get("PREFETCH", 4)

    train_loader = DataLoader(
        train_ds, batch_size=CFG["BATCH_SIZE"], sampler=sampler,
        num_workers=n_workers, pin_memory=True, persistent_workers=True,
        prefetch_factor=prefetch
    )
    val_loader = DataLoader(
        val_ds, batch_size=CFG["BATCH_SIZE"], shuffle=False,
        num_workers=max(1, n_workers//2), pin_memory=True,
        persistent_workers=True, prefetch_factor=prefetch
    )
    test_loader = DataLoader(
        CustomImageDataset(CFG["test_root"], val_tf, is_test=True),
        batch_size=CFG["BATCH_SIZE"], shuffle=False,
        num_workers=max(1, n_workers//2), pin_memory=True,
        persistent_workers=True, prefetch_factor=prefetch
    )
    return train_loader, val_loader, test_loader, full.classes
''')

# %%
# %%writefile train.py
import os, yaml, wandb, torch, timm, gc
import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm
from transformers import get_cosine_schedule_with_warmup
from torch.cuda.amp import autocast, GradScaler
from dataload import get_loaders, CFG

# ──────────────────────── 0. 환경 설정 ────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device.type == "cuda":
    print(f"🚀 Using GPU : {torch.cuda.get_device_name(0)}")
    torch.backends.cudnn.benchmark = True   # 속도 ↑
    torch.cuda.empty_cache()                # ↳ 캐시 정리
    torch.cuda.reset_peak_memory_stats()

# ──────────────────────── 1. 모델 정의 ────────────────────────
class BaseModel(nn.Module):
    def __init__(self, num_classes: int):
        super().__init__()
        self.backbone = timm.create_model(
            CFG["model"],
            pretrained=True,
            num_classes=num_classes,
            drop_path_rate=CFG.get("stochastic_depth", 0.0)
        )
    def forward(self, x):
        return self.backbone(x)

# ──────────────────────── 2. 학습 함수 ────────────────────────
def main():
    run = wandb.init(project="effb5-color", config=CFG)
    train_loader, val_loader, _, class_names = get_loaders()
    model = BaseModel(len(class_names)).to(device)

    # 파라미터 그룹 설정: 분류 헤드(10×lr)
    head, body = [], []
    for n, p in model.named_parameters():
        (head if "classifier" in n or "head" in n else body).append(p)
    optimizer = optim.AdamW([
        {"params": body, "lr": CFG["LEARNING_RATE"]},
        {"params": head, "lr": CFG["LEARNING_RATE"] * 10}
    ], weight_decay=0.05)

    criterion = nn.CrossEntropyLoss()
    scaler    = GradScaler()

    # 학습률 스케줄러
    total_steps = len(train_loader) * CFG["EPOCHS"]
    scheduler   = get_cosine_schedule_with_warmup(
        optimizer,
        int(total_steps * 0.1),         # warm-up 10 %
        total_steps
    )

    # 파라미터 수 출력
    total_params = sum(p.numel() for p in model.parameters())
    train_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"📊 Params: {total_params:,} (trainable {train_params:,})")

    best_loss, bad_epochs = float("inf"), 0

    for epoch in range(CFG["EPOCHS"]):
        # ─── Train ────────────────────────────────────────────
        model.train(); running = 0
        for imgs, labels in tqdm(train_loader, desc=f"[Train {epoch+1}]"):
            imgs, labels = imgs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            optimizer.zero_grad(set_to_none=True)
            with autocast():
                loss = criterion(model(imgs), labels)
            scaler.scale(loss).backward()
            scaler.step(optimizer); scaler.update()
            scheduler.step()
            running += loss.item()
        train_loss = running / len(train_loader)

        # ─── Validation ──────────────────────────────────────
        model.eval(); val_loss = 0; correct = total = 0
        with torch.no_grad():
            for imgs, labels in tqdm(val_loader, desc=f"[Val   {epoch+1}]"):
                imgs, labels = imgs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
                with autocast():
                    outs  = model(imgs)
                    loss  = criterion(outs, labels)
                val_loss += loss.item()
                correct  += (outs.argmax(1) == labels).sum().item()
                total    += labels.size(0)
        val_loss /= len(val_loader)
        val_acc   = 100 * correct / total

        # ─── GPU 메모리 모니터링 ──────────────────────────────
        if device.type == "cuda":
            mem_alloc   = torch.cuda.memory_allocated() / 1024**2
            peak_alloc  = torch.cuda.max_memory_allocated() / 1024**2
            print(f"🧠 GPU Mem  : {mem_alloc:.1f} MB (peak {peak_alloc:.1f} MB)")

        # ─── 로깅 & EarlyStopping ────────────────────────────
        wandb.log({"epoch": epoch+1,
                   "train_loss": train_loss,
                   "val_loss":   val_loss,
                   "val_acc":    val_acc,
                   "gpu_mem_MB": mem_alloc if device.type=="cuda" else 0})

        if val_loss < best_loss:                     # improvement
            best_loss, bad_epochs = val_loss, 0
            torch.save(model.state_dict(), "best_model.pth")
            print(f"📦  Best model saved (val_loss={val_loss:.4f})")
        else:
            bad_epochs += 1
            print(f"⚠️  No improvement {bad_epochs}/{CFG['patience']}")
            if bad_epochs >= CFG["patience"]:
                print(f"🛑 Early Stopping at epoch {epoch+1}")
                break

    # 훈련 종료 후 캐시 정리
    if device.type == "cuda":
        torch.cuda.empty_cache(); gc.collect()
        print("♻️  GPU cache cleared")

    run.finish()

if __name__ == "__main__":
    main()
# Out:
# Overwriting train.py

# %%
# 6. 학습 실행  ← 주석 제거!
# %cd /content          # 주석 없이 정확히
import os; os.environ["WANDB_MODE"]="offline"   # WandB 로그인 생략
from train import main
main()
# Out:
# [Errno 2] No such file or directory: '/content # 주석 없이 정확히'
# /content
# 🚀 Using GPU : NVIDIA A100-SXM4-40GB
# Tracking run with wandb version 0.20.1
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/122M [00:00<?, ?B/s]
# /content/train.py:46: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler    = GradScaler()
# 📊 Params: 29,152,188 (trainable 29,152,188)
# [Train 1]:   0%|          | 0/1657 [00:00<?, ?it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   0%|          | 1/1657 [00:06<2:47:14,  6.06s/it]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   0%|          | 2/1657 [00:06<1:12:01,  2.61s/it]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   0%|          | 8/1657 [00:07<08:33,  3.21it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   1%|          | 13/1657 [00:08<05:12,  5.26it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   1%|          | 19/1657 [00:08<04:17,  6.36it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   2%|▏         | 28/1657 [00:10<04:07,  6.57it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   2%|▏         | 39/1657 [00:11<04:13,  6.37it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   2%|▏         | 41/1657 [00:12<04:22,  6.17it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   3%|▎         | 46/1657 [00:13<04:15,  6.30it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   3%|▎         | 52/1657 [00:14<04:11,  6.38it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   4%|▍         | 63/1657 [00:15<04:26,  5.98it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   4%|▍         | 65/1657 [00:16<04:33,  5.82it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   4%|▍         | 70/1657 [00:17<04:26,  5.94it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   5%|▍         | 76/1657 [00:17<04:17,  6.14it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   5%|▍         | 82/1657 [00:18<04:04,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   5%|▌         | 90/1657 [00:20<04:00,  6.51it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   6%|▌         | 95/1657 [00:20<04:04,  6.39it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   6%|▋         | 104/1657 [00:22<04:04,  6.35it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   7%|▋         | 110/1657 [00:23<04:00,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   7%|▋         | 117/1657 [00:24<03:56,  6.52it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   7%|▋         | 121/1657 [00:25<04:55,  5.21it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   8%|▊         | 131/1657 [00:26<04:03,  6.27it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   8%|▊         | 134/1657 [00:27<04:00,  6.34it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   8%|▊         | 139/1657 [00:28<04:02,  6.25it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   9%|▉         | 146/1657 [00:29<04:08,  6.08it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:   9%|▉         | 152/1657 [00:30<03:55,  6.38it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  10%|▉         | 158/1657 [00:31<03:51,  6.48it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  10%|▉         | 163/1657 [00:31<03:57,  6.30it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  10%|█         | 169/1657 [00:32<03:50,  6.45it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  11%|█         | 177/1657 [00:34<03:49,  6.46it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  11%|█         | 182/1657 [00:34<03:51,  6.38it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  12%|█▏        | 191/1657 [00:36<03:44,  6.54it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  12%|█▏        | 197/1657 [00:37<03:42,  6.55it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  12%|█▏        | 202/1657 [00:37<03:46,  6.43it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  13%|█▎        | 210/1657 [00:39<03:43,  6.49it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  13%|█▎        | 216/1657 [00:40<03:42,  6.46it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  13%|█▎        | 222/1657 [00:41<03:48,  6.29it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  14%|█▍        | 229/1657 [00:42<03:51,  6.17it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  14%|█▍        | 234/1657 [00:43<04:00,  5.91it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  14%|█▍        | 239/1657 [00:43<03:50,  6.14it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  15%|█▍        | 247/1657 [00:45<03:53,  6.05it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  15%|█▌        | 253/1657 [00:46<03:42,  6.31it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  16%|█▌        | 259/1657 [00:47<03:33,  6.54it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  16%|█▌        | 265/1657 [00:47<03:39,  6.33it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  16%|█▋        | 271/1657 [00:48<03:34,  6.46it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  17%|█▋        | 277/1657 [00:49<03:40,  6.27it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  17%|█▋        | 284/1657 [00:50<03:34,  6.39it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  18%|█▊        | 290/1657 [00:51<03:30,  6.49it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  18%|█▊        | 298/1657 [00:53<03:26,  6.59it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  18%|█▊        | 304/1657 [00:54<03:26,  6.56it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  19%|█▉        | 312/1657 [00:55<03:29,  6.42it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  19%|█▉        | 322/1657 [00:56<03:33,  6.25it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  20%|█▉        | 324/1657 [00:57<03:31,  6.30it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  20%|█▉        | 330/1657 [00:58<03:24,  6.47it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  20%|██        | 336/1657 [00:59<03:20,  6.58it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  21%|██        | 342/1657 [00:59<03:25,  6.41it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  21%|██        | 348/1657 [01:00<03:24,  6.41it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  21%|██▏       | 355/1657 [01:01<03:21,  6.45it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  22%|██▏       | 363/1657 [01:03<03:15,  6.60it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  22%|██▏       | 369/1657 [01:04<03:15,  6.57it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  23%|██▎       | 374/1657 [01:04<03:16,  6.54it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  23%|██▎       | 383/1657 [01:06<03:21,  6.34it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  23%|██▎       | 388/1657 [01:07<03:29,  6.05it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  24%|██▎       | 393/1657 [01:07<03:19,  6.33it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  24%|██▍       | 401/1657 [01:09<03:24,  6.14it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  25%|██▍       | 407/1657 [01:10<03:12,  6.50it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  25%|██▍       | 412/1657 [01:10<03:20,  6.20it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  25%|██▌       | 420/1657 [01:12<03:16,  6.31it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  26%|██▌       | 426/1657 [01:13<03:06,  6.59it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  26%|██▌       | 431/1657 [01:13<03:16,  6.25it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  26%|██▋       | 438/1657 [01:14<03:07,  6.51it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  27%|██▋       | 444/1657 [01:15<03:12,  6.31it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  27%|██▋       | 451/1657 [01:16<03:04,  6.54it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  28%|██▊       | 463/1657 [01:18<03:02,  6.54it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  28%|██▊       | 465/1657 [01:19<03:00,  6.59it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  28%|██▊       | 471/1657 [01:20<03:00,  6.56it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  29%|██▉       | 482/1657 [01:21<03:04,  6.35it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  29%|██▉       | 484/1657 [01:22<03:10,  6.15it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  30%|██▉       | 490/1657 [01:23<03:04,  6.31it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  30%|██▉       | 495/1657 [01:23<03:09,  6.13it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  30%|███       | 502/1657 [01:24<02:56,  6.54it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  31%|███       | 509/1657 [01:25<02:54,  6.56it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  31%|███       | 517/1657 [01:27<02:53,  6.58it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  32%|███▏      | 523/1657 [01:28<03:00,  6.27it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  32%|███▏      | 528/1657 [01:28<02:55,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  32%|███▏      | 537/1657 [01:30<02:50,  6.56it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  33%|███▎      | 543/1657 [01:31<02:49,  6.56it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  33%|███▎      | 549/1657 [01:32<02:51,  6.47it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  34%|███▎      | 556/1657 [01:33<02:57,  6.19it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  34%|███▍      | 562/1657 [01:34<02:54,  6.27it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  34%|███▍      | 566/1657 [01:34<02:55,  6.22it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  35%|███▍      | 573/1657 [01:35<02:45,  6.54it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  35%|███▍      | 579/1657 [01:36<02:48,  6.39it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  35%|███▌      | 587/1657 [01:38<02:44,  6.49it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  36%|███▌      | 598/1657 [01:39<02:41,  6.55it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  36%|███▌      | 600/1657 [01:40<02:42,  6.49it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  37%|███▋      | 605/1657 [01:40<02:43,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  37%|███▋      | 613/1657 [01:42<02:39,  6.53it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  37%|███▋      | 618/1657 [01:42<02:45,  6.26it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  38%|███▊      | 624/1657 [01:43<02:45,  6.23it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  38%|███▊      | 631/1657 [01:44<02:41,  6.35it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  38%|███▊      | 637/1657 [01:45<02:44,  6.21it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  39%|███▉      | 644/1657 [01:47<02:39,  6.35it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  39%|███▉      | 650/1657 [01:48<02:38,  6.35it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  40%|███▉      | 656/1657 [01:48<02:33,  6.53it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  40%|████      | 663/1657 [01:49<02:31,  6.55it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  40%|████      | 669/1657 [01:50<02:39,  6.19it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  41%|████      | 675/1657 [01:51<02:32,  6.46it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  41%|████      | 683/1657 [01:53<02:34,  6.29it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  42%|████▏     | 689/1657 [01:54<02:27,  6.57it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  42%|████▏     | 697/1657 [01:55<02:26,  6.57it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  42%|████▏     | 703/1657 [01:56<02:36,  6.09it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  43%|████▎     | 708/1657 [01:57<02:31,  6.24it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  43%|████▎     | 716/1657 [01:58<02:28,  6.35it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  44%|████▎     | 721/1657 [01:59<02:33,  6.08it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  44%|████▍     | 727/1657 [02:00<02:39,  5.85it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  45%|████▍     | 739/1657 [02:01<02:24,  6.36it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  45%|████▍     | 741/1657 [02:02<02:27,  6.22it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  45%|████▌     | 746/1657 [02:03<02:23,  6.37it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  45%|████▌     | 753/1657 [02:04<02:17,  6.58it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  46%|████▌     | 759/1657 [02:05<02:19,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  46%|████▌     | 765/1657 [02:06<02:17,  6.47it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  47%|████▋     | 777/1657 [02:07<02:20,  6.27it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  47%|████▋     | 780/1657 [02:08<02:17,  6.39it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  47%|████▋     | 785/1657 [02:09<02:20,  6.22it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  48%|████▊     | 790/1657 [02:09<02:22,  6.10it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  48%|████▊     | 796/1657 [02:10<02:19,  6.17it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  48%|████▊     | 802/1657 [02:11<02:12,  6.45it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  49%|████▉     | 809/1657 [02:12<02:17,  6.17it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  49%|████▉     | 817/1657 [02:14<02:10,  6.43it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  50%|████▉     | 828/1657 [02:15<02:07,  6.52it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  50%|█████     | 830/1657 [02:16<02:06,  6.53it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  50%|█████     | 836/1657 [02:17<02:08,  6.41it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  51%|█████     | 841/1657 [02:17<02:07,  6.40it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  51%|█████▏    | 850/1657 [02:19<02:04,  6.49it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  52%|█████▏    | 855/1657 [02:20<02:04,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  52%|█████▏    | 861/1657 [02:21<02:07,  6.24it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  53%|█████▎    | 873/1657 [02:22<02:00,  6.53it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  53%|█████▎    | 875/1657 [02:23<02:01,  6.46it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  53%|█████▎    | 880/1657 [02:23<01:59,  6.51it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  54%|█████▎    | 888/1657 [02:25<02:03,  6.23it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  54%|█████▍    | 894/1657 [02:26<02:03,  6.20it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  54%|█████▍    | 899/1657 [02:26<02:03,  6.15it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  55%|█████▍    | 907/1657 [02:28<01:57,  6.39it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  55%|█████▌    | 913/1657 [02:29<01:56,  6.40it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  55%|█████▌    | 919/1657 [02:30<01:55,  6.40it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  56%|█████▌    | 924/1657 [02:30<01:52,  6.53it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  56%|█████▋    | 933/1657 [02:32<01:49,  6.63it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  57%|█████▋    | 944/1657 [02:33<01:49,  6.52it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  57%|█████▋    | 946/1657 [02:34<01:49,  6.52it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  57%|█████▋    | 952/1657 [02:35<01:47,  6.57it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  58%|█████▊    | 958/1657 [02:36<01:48,  6.43it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  58%|█████▊    | 964/1657 [02:37<01:48,  6.36it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  59%|█████▊    | 970/1657 [02:37<01:50,  6.21it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  59%|█████▉    | 977/1657 [02:39<01:52,  6.07it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  59%|█████▉    | 982/1657 [02:39<01:44,  6.47it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  60%|█████▉    | 988/1657 [02:40<01:50,  6.06it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  60%|██████    | 995/1657 [02:41<01:42,  6.45it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  60%|██████    | 1001/1657 [02:42<01:41,  6.45it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  61%|██████    | 1010/1657 [02:44<01:43,  6.27it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  61%|██████▏   | 1016/1657 [02:45<01:39,  6.46it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  62%|██████▏   | 1023/1657 [02:46<01:36,  6.59it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  62%|██████▏   | 1029/1657 [02:47<01:34,  6.62it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  62%|██████▏   | 1034/1657 [02:47<01:35,  6.56it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  63%|██████▎   | 1041/1657 [02:48<01:37,  6.32it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  63%|██████▎   | 1049/1657 [02:50<01:35,  6.36it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  64%|██████▎   | 1055/1657 [02:51<01:35,  6.30it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  64%|██████▍   | 1060/1657 [02:52<01:39,  6.01it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  64%|██████▍   | 1066/1657 [02:52<01:30,  6.50it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  65%|██████▍   | 1072/1657 [02:53<01:30,  6.47it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  65%|██████▌   | 1080/1657 [02:55<01:27,  6.57it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  66%|██████▌   | 1087/1657 [02:56<01:27,  6.54it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  66%|██████▌   | 1092/1657 [02:56<01:26,  6.55it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  66%|██████▋   | 1099/1657 [02:57<01:26,  6.47it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  67%|██████▋   | 1107/1657 [02:59<01:22,  6.63it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  67%|██████▋   | 1113/1657 [03:00<01:21,  6.64it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  68%|██████▊   | 1119/1657 [03:01<01:28,  6.08it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  68%|██████▊   | 1126/1657 [03:02<01:27,  6.09it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  68%|██████▊   | 1131/1657 [03:02<01:24,  6.23it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  69%|██████▊   | 1137/1657 [03:03<01:21,  6.39it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  69%|██████▉   | 1143/1657 [03:04<01:19,  6.50it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  69%|██████▉   | 1150/1657 [03:05<01:16,  6.60it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  70%|██████▉   | 1156/1657 [03:06<01:17,  6.43it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  70%|███████   | 1165/1657 [03:08<01:15,  6.50it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  71%|███████   | 1170/1657 [03:09<01:22,  5.92it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  71%|███████   | 1176/1657 [03:09<01:14,  6.47it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  71%|███████▏  | 1184/1657 [03:11<01:11,  6.65it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  72%|███████▏  | 1190/1657 [03:12<01:10,  6.65it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  72%|███████▏  | 1195/1657 [03:12<01:11,  6.48it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  73%|███████▎  | 1202/1657 [03:13<01:14,  6.15it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  73%|███████▎  | 1208/1657 [03:14<01:12,  6.19it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  73%|███████▎  | 1215/1657 [03:16<01:12,  6.12it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  74%|███████▎  | 1221/1657 [03:17<01:10,  6.17it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  74%|███████▍  | 1229/1657 [03:18<01:06,  6.40it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  75%|███████▍  | 1240/1657 [03:19<01:04,  6.43it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  75%|███████▍  | 1242/1657 [03:20<01:05,  6.29it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  75%|███████▌  | 1248/1657 [03:21<01:03,  6.43it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  76%|███████▌  | 1253/1657 [03:21<01:02,  6.48it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  76%|███████▌  | 1259/1657 [03:22<01:01,  6.43it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  76%|███████▋  | 1266/1657 [03:23<01:00,  6.51it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  77%|███████▋  | 1272/1657 [03:24<01:01,  6.30it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  77%|███████▋  | 1278/1657 [03:25<01:01,  6.19it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  78%|███████▊  | 1285/1657 [03:26<00:59,  6.25it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  78%|███████▊  | 1292/1657 [03:28<00:57,  6.37it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  78%|███████▊  | 1297/1657 [03:28<00:58,  6.14it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  79%|███████▊  | 1303/1657 [03:29<00:56,  6.30it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 1]:  79%|███████▉  | 1310/1657 [03:30<00:55,  6.30it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# ...
#   with autocast():
# [Train 3]:  38%|███▊      | 624/1657 [01:39<02:45,  6.25it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  38%|███▊      | 632/1657 [01:40<02:40,  6.38it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  39%|███▊      | 638/1657 [01:41<02:39,  6.38it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  39%|███▉      | 643/1657 [01:42<02:38,  6.40it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  39%|███▉      | 652/1657 [01:43<02:42,  6.17it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  40%|███▉      | 657/1657 [01:44<02:40,  6.23it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  40%|███▉      | 662/1657 [01:45<02:37,  6.31it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  40%|████      | 668/1657 [01:46<02:36,  6.34it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  41%|████      | 675/1657 [01:47<02:32,  6.45it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  41%|████      | 683/1657 [01:48<02:31,  6.42it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  42%|████▏     | 689/1657 [01:49<02:29,  6.49it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  42%|████▏     | 695/1657 [01:50<02:33,  6.27it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  42%|████▏     | 700/1657 [01:51<02:28,  6.46it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  43%|████▎     | 706/1657 [01:52<02:28,  6.40it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  43%|████▎     | 713/1657 [01:53<02:27,  6.39it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  43%|████▎     | 719/1657 [01:54<02:27,  6.36it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  44%|████▍     | 727/1657 [01:55<02:29,  6.21it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  44%|████▍     | 733/1657 [01:56<02:29,  6.17it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  45%|████▍     | 738/1657 [01:57<02:32,  6.04it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  45%|████▌     | 746/1657 [01:58<02:21,  6.45it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  45%|████▌     | 752/1657 [01:59<02:25,  6.22it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  46%|████▌     | 758/1657 [02:00<02:25,  6.19it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  46%|████▌     | 765/1657 [02:01<02:19,  6.39it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  46%|████▋     | 770/1657 [02:02<02:18,  6.38it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  47%|████▋     | 776/1657 [02:03<02:16,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  47%|████▋     | 782/1657 [02:04<02:17,  6.37it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  48%|████▊     | 791/1657 [02:05<02:16,  6.34it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  48%|████▊     | 801/1657 [02:07<02:25,  5.88it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  48%|████▊     | 802/1657 [02:07<02:25,  5.87it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  49%|████▉     | 808/1657 [02:08<02:19,  6.11it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  49%|████▉     | 814/1657 [02:09<02:18,  6.08it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  49%|████▉     | 820/1657 [02:10<02:12,  6.33it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  50%|████▉     | 828/1657 [02:11<02:17,  6.01it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  51%|█████     | 839/1657 [02:13<02:13,  6.14it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  51%|█████     | 841/1657 [02:13<02:09,  6.29it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  51%|█████     | 846/1657 [02:14<02:05,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  51%|█████▏    | 851/1657 [02:15<02:06,  6.35it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  52%|█████▏    | 860/1657 [02:16<02:03,  6.46it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  52%|█████▏    | 866/1657 [02:17<02:03,  6.40it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  53%|█████▎    | 877/1657 [02:19<02:02,  6.37it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  53%|█████▎    | 879/1657 [02:19<02:01,  6.40it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  53%|█████▎    | 884/1657 [02:20<02:05,  6.17it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  54%|█████▎    | 890/1657 [02:21<02:05,  6.10it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  54%|█████▍    | 902/1657 [02:23<01:59,  6.34it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  55%|█████▍    | 904/1657 [02:23<01:59,  6.30it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  55%|█████▍    | 909/1657 [02:24<01:58,  6.29it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  55%|█████▌    | 917/1657 [02:25<01:55,  6.43it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  56%|█████▌    | 922/1657 [02:26<01:54,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  56%|█████▌    | 927/1657 [02:27<01:57,  6.19it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  56%|█████▋    | 933/1657 [02:28<01:53,  6.35it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  57%|█████▋    | 940/1657 [02:29<01:53,  6.30it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  57%|█████▋    | 947/1657 [02:30<01:50,  6.45it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  58%|█████▊    | 956/1657 [02:32<02:03,  5.68it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  58%|█████▊    | 958/1657 [02:32<01:56,  6.00it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  58%|█████▊    | 964/1657 [02:33<01:56,  5.97it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  58%|█████▊    | 969/1657 [02:34<01:53,  6.07it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  59%|█████▉    | 975/1657 [02:35<01:55,  5.91it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  59%|█████▉    | 983/1657 [02:36<01:44,  6.44it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  60%|█████▉    | 994/1657 [02:38<01:44,  6.34it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  60%|██████    | 996/1657 [02:38<01:43,  6.38it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  60%|██████    | 1002/1657 [02:39<01:43,  6.34it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  61%|██████    | 1008/1657 [02:40<01:41,  6.43it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  61%|██████▏   | 1019/1657 [02:42<01:37,  6.54it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  62%|██████▏   | 1021/1657 [02:42<01:39,  6.39it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  62%|██████▏   | 1026/1657 [02:43<01:41,  6.21it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  62%|██████▏   | 1032/1657 [02:44<01:37,  6.42it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  63%|██████▎   | 1041/1657 [02:45<01:37,  6.34it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  63%|██████▎   | 1046/1657 [02:46<01:47,  5.67it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  64%|██████▎   | 1053/1657 [02:47<01:34,  6.42it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  64%|██████▍   | 1059/1657 [02:48<01:34,  6.34it/s]/content/train.py:69: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# [Train 3]:  64%|██████▍   | 1060/1657 [02:48<01:34,  6.35it/s]

# %%
# 2) 추론 & 제출 파일 생성
# !python inference.py
# !head submission_tta.csv    # 결과 미리보기
